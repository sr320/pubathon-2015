# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.__version__
# Out:
# '0.11.0'

# %%
# %matplotlib inline

# %%
tally=pd.read_csv("./data/tally.csv")
tally['total'] = tally.sum(axis=1)

# %% [markdown]
# # Scoreboard

# %%
tally.sort(columns='total', ascending=[0])
# Out:
#         Name   title   url   bonus-1   week2-url   week3      total
# 0        Sam       0     0         0           0       0 NaN      0
# 4       Lisa       0     0         0           0       0 NaN      0
# 5     Hannah       0     0         0           0       0 NaN      0
# 6   Jonathan       0     0         0           0       0 NaN      0
# 7      Grace       0     0         0           0       0 NaN      0
# 10     Brent       0     0         0           0       0 NaN      0
# 11     Katie       0     0         0           0       0 NaN      0
# 12       Mac       0     0         0           0       0 NaN      0
# 1       Jake       5     5         0           0       0 NaN     10
# 8     Claire       0     0         0          10       0 NaN     10
# 2     Steven       5     5         0          10       0 NaN     20
# 3        Jay       5     5        10           0       0 NaN     20
# 9       Emma       0     0         0           0      20 NaN     20

# %%
# tally.describe()
